# %%
from tpulse import TinkoffPulse
from pprint import pp
pulse = TinkoffPulse()
user_info = pulse.get_user_info("Dengi_nespyat_Irina")
pp(user_info)
# Out:
# {'id': 'f01a9c6c-34ea-42c1-afa8-69d626e51151',
#  'type': 'personal',
#  'nickname': 'Dengi_nespyat_Irina',
#  'status': 'open',
#  'image': '82554fac-125c-44b7-939e-97ac0cfb39ce',
#  'block': False,
#  'description': '🔥 Лайфстайл: https://instagram.com/ira.akhmadullina\n'
#                 '\n'
#                 '✈️ Телеграм: https: //t.me/ira_Akhmadullina\n'
#                 '\n'
#                 '🎙️ Подкаст - 7 место в категории Инвестиции: \n'
#                 'https://podcasts.apple.com/ru/podcast/finiq/id1510450233?l=en\n'
#                 '\n'
#                 '🎬 Youtube - выпуски каждую неделю:\n'
#                 ' https://youtube.com/@ira.akhmadullina',
#  'followersCount': 49382,
#  'followingCount': 27,
#  'isLead': False,
#  'isMuted': False,
#  'serviceTags': [{'id': 'verified'},
#                  {'id': 'popular'},
#                  {'id': 'tracking-master'}],
#  'statistics': {'totalAmountRange': {'lower': 1000000, 'upper': 5000000},
# ...

# %%
ticker_posts = pulse.get_posts_by_ticker("AAPL")
pp(ticker_posts)

pp(ticker_posts["items"][5])
# Почему-то тут в строке 'text': пустая строка
# Out:
# {'nextCursor': 9285123,
#  'hasNext': True,
#  'items': [{'id': '12ab45ee-6e3b-4cd2-968a-12d548e2fe15',
#             'text': '',
#             'likesCount': 0,
#             'commentsCount': 0,
#             'isLiked': False,
#             'inserted': '2023-10-29T19:29:29.772+03:00',
#             'isEditable': False,
#             'instruments': [{'type': 'share',
#                              'ticker': 'AAPL',
#                              'lastPrice': 168.01,
#                              'currency': 'usd',
#                              'image': 'US0378331005.png',
#                              'briefName': 'Apple',
#                              'relativeDailyYield': 0.44,
#                              'price': 168.01,
#                              'relativeYield': 0.0},
#                             {'type': 'share',
#                              'ticker': 'MRNA',
#                              'lastPrice': 71.9,
#                              'currency': 'usd',
# ...

# %%
user_posts = pulse.get_posts_by_user_id("f01a9c6c-34ea-42c1-afa8-69d626e51151")
# pp(user_posts)
pp(user_posts["items"][1])
# Почему-то тут в строке 'text': пустая строка
# Out:
# {'id': '4fb49a16-3891-40e9-a41b-a796a2d59f60',
#  'text': '',
#  'likesCount': 81,
#  'commentsCount': 24,
#  'isLiked': False,
#  'inserted': '2023-10-10T16:06:39.326+03:00',
#  'isEditable': False,
#  'instruments': [{'type': 'currency',
#                   'ticker': 'USDRUB',
#                   'lastPrice': 94.125,
#                   'currency': 'rub',
#                   'image': 'USD1.png',
#                   'briefName': 'Доллар США',
#                   'relativeDailyYield': 0.18,
#                   'price': 99.815,
#                   'relativeYield': -5.7}],
#  'profiles': [{'id': '838b20c1-2a2c-4cf4-979d-7b8ca506f8fa',
#                'nickname': 'Invest_with_Irina'}],
#  'serviceTags': [],
#  'profileId': 'f01a9c6c-34ea-42c1-afa8-69d626e51151',
#  'nickname': 'Dengi_nespyat_Irina',
#  'image': '82554fac-125c-44b7-939e-97ac0cfb39ce',
#  'postImages': [{'id': 'b2e0fc20-06b5-401e-867d-a4beaff36e6e',
#                  'height': 1010,
#                  'width': 1280}],
# ...
